# %% [markdown]
# Classifi

# %% [markdown]
# ###Classification Report
#
# - Metrics - Precision, Recall, F1 score
# - Each class will have it own metrics
# - Macro avg : average all the metrics for the individual classes
# - Weighted avg : considers the weight of each class as well
