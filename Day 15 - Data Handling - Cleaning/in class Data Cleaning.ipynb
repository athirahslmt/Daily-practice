# %%
data = [
    {"Transaction ID": 1001, "Customer Name": "Alice Smith", "Email": "alice@example.com", "Product": "Laptop", "Quantity": 1, "Price": 1200.00, "Purchase Date": "2024-09-15", "Delivery Status": True},
    {"Transaction ID": 1001, "Customer Name": "Alice Smith", "Email": "alice@example.com", "Product": "Laptop", "Quantity": 1, "Price": 1200.00, "Purchase Date": "2024-09-15", "Delivery Status": True},
    {"Transaction ID": 1002, "Customer Name": "Bob Jones", "Email": None, "Product": "Headphones", "Quantity": 2, "Price": 150.00, "Purchase Date": "2024-09-16", "Delivery Status": True},
    {"Transaction ID": 1003, "Customer Name": "Charlie Johnson", "Email": "charlie#example.com", "Product": "Smartphone", "Quantity": 1, "Price": 800.00, "Purchase Date": "16/09/2024", "Delivery Status": True},
    {"Transaction ID": 1004, "Customer Name": "David Lee", "Email": "david.lee@example.com", "Product": "Laptop", "Quantity": 1, "Price": 1200.00, "Purchase Date": "2024-09-17", "Delivery Status": False},
    {"Transaction ID": 1005, "Customer Name": "Eve Martinez", "Email": "eve.martinez@example.com", "Product": "Smartwatch", "Quantity": 3, "Price": None, "Purchase Date": "17th Sep 2024", "Delivery Status": True},
    {"Transaction ID": 1006, "Customer Name": "Frank Wright", "Email": None, "Product": "Tablet", "Quantity": None, "Price": 600.00, "Purchase Date": "2024-09-18", "Delivery Status": False},
    {"Transaction ID": 1007, "Customer Name": "Grace Lee", "Email": "grace.lee@example.com", "Product": "Laptop", "Quantity": 1, "Price": 1200.00, "Purchase Date": "2024-09-19", "Delivery Status": True},
    {"Transaction ID": 1008, "Customer Name": "Hank Brown", "Email": "hank.brown@example.com", "Product": "Monitor", "Quantity": 2, "Price": 300.00, "Purchase Date": "09/19/2024", "Delivery Status": True},
    {"Transaction ID": 1009, "Customer Name": "Ivy Thompson", "Email": None, "Product": "Keyboard", "Quantity": 2, "Price": 100.00, "Purchase Date": "2024/09/20", "Delivery Status": False},
    {"Transaction ID": 1009, "Customer Name": "Ivy Thompson", "Email": None, "Product": "Keyboard", "Quantity": 2, "Price": 100.00, "Purchase Date": "2024/09/20", "Delivery Status": False},{"Transaction ID": 1009, "Customer Name": "Ivy Thompson", "Email": None, "Product": "Keyboard", "Quantity": 2, "Price": 100.00, "Purchase Date": "2024/09/20", "Delivery Status": False},
    {"Transaction ID": 1010, "Customer Name": "Jack Davis", "Email": "jack@example.com", "Product": "Mouse", "Quantity": 5, "Price": 50.00, "Purchase Date": "2024-09-21", "Delivery Status": True},
    {"Transaction ID": 1011, "Customer Name": "Alice Smith", "Email": "alice@example.com", "Product": "Laptop", "Quantity": 1, "Price": 1200.00, "Purchase Date": "2024-09-15", "Delivery Status": True},  # Duplicate entry
    {"Transaction ID": 1012, "Customer Name": "Kurt Evans", "Email": "kurt.evans@example.com", "Product": "Smartwatch", "Quantity": -1, "Price": 200.00, "Purchase Date": "2024-09-22", "Delivery Status": True},  # Outlier quantity
    {"Transaction ID": 1013, "Customer Name": "Liam Adams", "Email": "liam.adams@example.com", "Product": "Headphones", "Quantity": 2, "Price": 150.00, "Purchase Date": "2024-09-23", "Delivery Status": False},
    {"Transaction ID": 1014, "Customer Name": "Mia Clark", "Email": "mia.clark@example.com", "Product": None, "Quantity": 1, "Price": 0, "Purchase Date": "2024-09-24", "Delivery Status": True},  # Price anomaly
    {"Transaction ID": 1015, "Customer Name": "Nina Turner", "Email": None, "Product": "Tablet", "Quantity": 1, "Price": 600.00, "Purchase Date": "24-09-2024", "Delivery Status": True},
    {"Transaction ID": 1016, "Customer Name": "Oscar Harris", "Email": "oscar.harris@example.com", "Product": "Laptop", "Quantity": 2, "Price": 1200.00, "Purchase Date": "2024-09-25", "Delivery Status": True},
    {"Transaction ID": 1017, "Customer Name": "Paul Young", "Email": "paulyoung", "Product": "Monitor", "Quantity": 2, "Price": 300.00, "Purchase Date": "09/25/2024", "Delivery Status": True},
    {"Transaction ID": 1017, "Customer Name": "Paul Young", "Email": "paulyoung", "Product": "Monitor", "Quantity": 2, "Price": 300.00, "Purchase Date": "09/25/2024", "Delivery Status": True},
    {"Transaction ID": 1018, "Customer Name": "Quinn Lopez", "Email": None, "Product": "Smartphone", "Quantity": 1, "Price": 800.00, "Purchase Date": "2024-09-26", "Delivery Status": False},
    {"Transaction ID": 1019, "Customer Name": "Rachel Scott", "Email": "rachel.scott@example.com", "Product": "Keyboard", "Quantity": 2, "Price": 100.00, "Purchase Date": "2024-09-27", "Delivery Status": True},
    {"Transaction ID": 1020, "Customer Name": "Steve King", "Email": "steve.king@example.com", "Product": "Mouse", "Quantity": None, "Price": 50.00, "Purchase Date": "2024-09-28", "Delivery Status": True},
]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
df = pd.DataFrame(data)
df.head()
# Out:
#    Transaction ID    Customer Name                  Email     Product  \
# 0            1001      Alice Smith      alice@example.com      Laptop
# 1            1001      Alice Smith      alice@example.com      Laptop
# 2            1002        Bob Jones                   None  Headphones
# 3            1003  Charlie Johnson    charlie#example.com  Smartphone
# 4            1004        David Lee  david.lee@example.com      Laptop
#
#    Quantity   Price Purchase Date  Delivery Status
# 0       1.0  1200.0    2024-09-15             True
# 1       1.0  1200.0    2024-09-15             True
# 2       2.0   150.0    2024-09-16             True
# 3       1.0   800.0    16/09/2024             True
# 4       1.0  1200.0    2024-09-17            False

# %%
learners = {
        'names' : ['idrees','ibrahim','hazira','mel','aisyah','amin']
    }

# %%
x = pd.DataFrame(learners)
x
# Out:
#      names
# 0   idrees
# 1  ibrahim
# 2   hazira
# 3      mel
# 4   aisyah
# 5     amin

# %%
#create a new column, state in this

x['state'] = ['J & K','Selangor','N9','Johor','Selangor','Penang']
x['state2']={'J & K','Selangor','N9','Johor','Selangor','Penang'}
x['state3']=[]
x

# %%
x['state']=[0:8,1:1,2:1,3:4:9,4:np.nan,5:None]
x['state']=[1:1,2:1,3:1,4:1,5:1,6:1]
x

# %%
x['state']=(1,2,34,56,76,87)

# %%
#Access Amin data

x1 = x['state'][5]
x1
type(x1)

# %% [markdown]
# - when there is no value
# - empty
# - missing value

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Transaction ID   20 non-null     int64
#  1   Customer Name    20 non-null     object
#  2   Email            15 non-null     object
#  3   Product          19 non-null     object
#  4   Quantity         18 non-null     float64
#  5   Price            19 non-null     float64
#  6   Purchase Date    20 non-null     object
#  7   Delivery Status  20 non-null     bool
# dtypes: bool(1), float64(2), int64(1), object(4)
# memory usage: 1.2+ KB

# %%
df.describe() 
#related to numerical
#check for statistic
# Out:
#        Transaction ID   Quantity        Price
# count        20.00000  18.000000    19.000000
# mean       1010.50000   1.611111   536.842105
# std           5.91608   1.195033   472.241142
# min        1001.00000  -1.000000     0.000000
# 25%        1005.75000   1.000000   125.000000
# 50%        1010.50000   1.500000   300.000000
# 75%        1015.25000   2.000000  1000.000000
# max        1020.00000   5.000000  1200.000000

# %%
df.describe(include='all') 
#include all - take column
# Out:
#         Transaction ID Customer Name              Email Product   Quantity  \
# count         20.00000            20                 15      19  18.000000
# unique             NaN            19                 14       8        NaN
# top                NaN   Alice Smith  alice@example.com  Laptop        NaN
# freq               NaN             2                  2       5        NaN
# mean        1010.50000           NaN                NaN     NaN   1.611111
# std            5.91608           NaN                NaN     NaN   1.195033
# min         1001.00000           NaN                NaN     NaN  -1.000000
# 25%         1005.75000           NaN                NaN     NaN   1.000000
# 50%         1010.50000           NaN                NaN     NaN   1.500000
# 75%         1015.25000           NaN                NaN     NaN   2.000000
# max         1020.00000           NaN                NaN     NaN   5.000000
#
#               Price Purchase Date Delivery Status
# count     19.000000            20              20
# unique          NaN            19               2
# top             NaN    2024-09-15            True
# freq            NaN             2              15
# mean     536.842105           NaN             NaN
# std      472.241142           NaN             NaN
# min        0.000000           NaN             NaN
# 25%      125.000000           NaN             NaN
# 50%      300.000000           NaN             NaN
# 75%     1000.000000           NaN             NaN
# max     1200.000000           NaN             NaN

# %%
df.sample(5)
#show random sample entry
# Out:
#     Transaction ID Customer Name                   Email     Product  \
# 1             1002     Bob Jones                    None  Headphones
# 11            1012    Kurt Evans  kurt.evans@example.com  Smartwatch
# 5             1006  Frank Wright                    None      Tablet
# 12            1013    Liam Adams  liam.adams@example.com  Headphones
# 13            1014     Mia Clark   mia.clark@example.com        None
#
#     Quantity  Price Purchase Date  Delivery Status
# 1        2.0  150.0    2024-09-16             True
# 11      -1.0  200.0    2024-09-22             True
# 5        NaN  600.0    2024-09-18            False
# 12       2.0  150.0    2024-09-23            False
# 13       1.0    0.0    2024-09-24             True

# %%
countnull = df.isnull().sum()
#give number of null value
#same df.sum() - will take only interger value

sns.barplot(data=countnull)
plt.xticks(rotation = 45, horizontalalignment='right', fontsize=8)
# Out:
# ([0, 1, 2, 3, 4, 5, 6, 7],
#  [Text(0, 0, 'Transaction ID'),
#   Text(1, 0, 'Customer Name'),
#   Text(2, 0, 'Email'),
#   Text(3, 0, 'Product'),
#   Text(4, 0, 'Quantity'),
#   Text(5, 0, 'Price'),
#   Text(6, 0, 'Purchase Date'),
#   Text(7, 0, 'Delivery Status')])

# %%
print(countnull)
# Out:
# Transaction ID     0
# Customer Name      0
# Email              5
# Product            1
# Quantity           2
# Price              1
# Purchase Date      0
# Delivery Status    0
# dtype: int64

# %%
df.isnull().count()
#count all value
# Out:
# Transaction ID     20
# Customer Name      20
# Email              20
# Product            20
# Quantity           20
# Price              20
# Purchase Date      20
# Delivery Status    20
# dtype: int64

# %%
x = countnull.index
y = countnull

plt.bar(x,y)
plt.xticks(rotation = 45, horizontalalignment='right', fontsize=8)
# Out:
# ([0, 1, 2, 3, 4, 5, 6, 7],
#  [Text(0, 0, 'Transaction ID'),
#   Text(1, 0, 'Customer Name'),
#   Text(2, 0, 'Email'),
#   Text(3, 0, 'Product'),
#   Text(4, 0, 'Quantity'),
#   Text(5, 0, 'Price'),
#   Text(6, 0, 'Purchase Date'),
#   Text(7, 0, 'Delivery Status')])

# %%
for col in df.columns:
    missing = df[col].isnull().sum()
    total = len(df)

    bar = ' '*int((missing/total) * 20) #simple visualization

    print(f' {col:15} {missing} / {total} missing {bar}')
# Out:
#  Transaction ID  0 / 20 missing
#  Customer Name   0 / 20 missing
#  Email           5 / 20 missing
#  Product         1 / 20 missing
#  Quantity        2 / 20 missing
#  Price           1 / 20 missing
#  Purchase Date   0 / 20 missing
#  Delivery Status 0 / 20 missing

# %%
for i in countnull:
    missing = countnull.values
    total = len(df)

    bar = '| '* int((missing[i]+1) + 1) #simple visualization

    print(f' {countnull.index[i]:15}  missing : {bar}')
# Out:
#  Transaction ID   missing : | |
#  Transaction ID   missing : | |
#  Price            missing : | | |
#  Customer Name    missing : | |
#  Email            missing : | | | | | | |
#  Customer Name    missing : | |
#  Transaction ID   missing : | |
#  Transaction ID   missing : | |

# %%
x = "a"
y = 'b'

x = 8.4444455555555
y = 5.222233344555
x1=5.0

print(f'{x1:100} missing : {y}')
# Out:
#                                                                                                  5.0 missing : 5.222233344555

# %%
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# dtype: bool

# %%
df.duplicated()
# Out:
# 0     False
# 1      True
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10     True
# 11     True
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20     True
# 21    False
# 22    False
# 23    False
# dtype: bool

# %%
df.duplicated().sum()
# Out:
# np.int64(4)

# %%
df['Customer Name'].duplicated().sum()
# Out:
# np.int64(5)

# %%
data2 = {
    "Name": ["Alice", "Bob", "Charlie", "David", "Eve"],
    "Age": [25, 30, 35, 20, 40],  # 200 is an outlier
}
 
df2 = pd.DataFrame(data2)
df2
# Out:
#       Name  Age
# 0    Alice   25
# 1      Bob   30
# 2  Charlie   35
# 3    David   20
# 4      Eve   40

# %%
plt.boxplot(df2['Age'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x235c97d56a0>,
#   <matplotlib.lines.Line2D at 0x235c97d57f0>],
#  'caps': [<matplotlib.lines.Line2D at 0x235c97d5940>,
#   <matplotlib.lines.Line2D at 0x235c97d5a90>],
#  'boxes': [<matplotlib.lines.Line2D at 0x235c97d5550>],
#  'medians': [<matplotlib.lines.Line2D at 0x235c97d5be0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x235c97d5d30>],
#  'means': []}

# %%
dfnew.isnull().sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 dfnew.isnull().sum()
#
# NameError: name 'dfnew' is not defined

# %%
dfnew.dropna(subset=['Quantity','Price'], inplace=True)
dfnew
# Out:
#     Transaction ID    Customer Name                     Email     Product  \
# 0             1001      Alice Smith         alice@example.com      Laptop
# 1             1001      Alice Smith         alice@example.com      Laptop
# 3             1003  Charlie Johnson       charlie#example.com  Smartphone
# 4             1004        David Lee     david.lee@example.com      Laptop
# 7             1007        Grace Lee     grace.lee@example.com      Laptop
# 8             1008       Hank Brown    hank.brown@example.com     Monitor
# 12            1010       Jack Davis          jack@example.com       Mouse
# 13            1011      Alice Smith         alice@example.com      Laptop
# 14            1012       Kurt Evans    kurt.evans@example.com  Smartwatch
# 15            1013       Liam Adams    liam.adams@example.com  Headphones
# 18            1016     Oscar Harris  oscar.harris@example.com      Laptop
# 19            1017       Paul Young                 paulyoung     Monitor
# 20            1017       Paul Young                 paulyoung     Monitor
# 22            1019     Rachel Scott  rachel.scott@example.com    Keyboard
#
#     Quantity   Price Purchase Date  Delivery Status
# 0        1.0  1200.0    2024-09-15             True
# 1        1.0  1200.0    2024-09-15             True
# 3        1.0   800.0    16/09/2024             True
# 4        1.0  1200.0    2024-09-17            False
# 7        1.0  1200.0    2024-09-19             True
# 8        2.0   300.0    09/19/2024             True
# 12       5.0    50.0    2024-09-21             True
# 13       1.0  1200.0    2024-09-15             True
# 14      -1.0   200.0    2024-09-22             True
# 15       2.0   150.0    2024-09-23            False
# 18       2.0  1200.0    2024-09-25             True
# 19       2.0   300.0    09/25/2024             True
# 20       2.0   300.0    09/25/2024             True
# 22       2.0   100.0    2024-09-27             True

# %% [markdown]
# Handling missing value

# %%
#to create new copy of data frame
dfnew = df.copy()

# %%
dfnew['Price'][0:1]
dfnew
# Out:
#     Transaction ID    Customer Name                     Email     Product  \
# 0             1001      Alice Smith         alice@example.com      Laptop
# 1             1001      Alice Smith         alice@example.com      Laptop
# 2             1002        Bob Jones                      None  Headphones
# 3             1003  Charlie Johnson       charlie#example.com  Smartphone
# 4             1004        David Lee     david.lee@example.com      Laptop
# 5             1005     Eve Martinez  eve.martinez@example.com  Smartwatch
# 6             1006     Frank Wright                      None      Tablet
# 7             1007        Grace Lee     grace.lee@example.com      Laptop
# 8             1008       Hank Brown    hank.brown@example.com     Monitor
# 9             1009     Ivy Thompson                      None    Keyboard
# 10            1009     Ivy Thompson                      None    Keyboard
# 11            1009     Ivy Thompson                      None    Keyboard
# 12            1010       Jack Davis          jack@example.com       Mouse
# 13            1011      Alice Smith         alice@example.com      Laptop
# 14            1012       Kurt Evans    kurt.evans@example.com  Smartwatch
# 15            1013       Liam Adams    liam.adams@example.com  Headphones
# 16            1014        Mia Clark     mia.clark@example.com        None
# 17            1015      Nina Turner                      None      Tablet
# 18            1016     Oscar Harris  oscar.harris@example.com      Laptop
# 19            1017       Paul Young                 paulyoung     Monitor
# 20            1017       Paul Young                 paulyoung     Monitor
# 21            1018      Quinn Lopez                      None  Smartphone
# 22            1019     Rachel Scott  rachel.scott@example.com    Keyboard
# 23            1020       Steve King    steve.king@example.com       Mouse
#
#     Quantity   Price  Purchase Date  Delivery Status
# 0        1.0   800.0     2024-09-15             True
# 1        1.0  1200.0     2024-09-15             True
# 2        2.0   150.0     2024-09-16             True
# 3        1.0   800.0     16/09/2024             True
# 4        1.0  1200.0     2024-09-17            False
# 5        3.0     NaN  17th Sep 2024             True
# 6        NaN   600.0     2024-09-18            False
# 7        1.0  1200.0     2024-09-19             True
# 8        2.0   300.0     09/19/2024             True
# 9        2.0   100.0     2024/09/20            False
# 10       2.0   100.0     2024/09/20            False
# 11       2.0   100.0     2024/09/20            False
# 12       5.0    50.0     2024-09-21             True
# 13       1.0  1200.0     2024-09-15             True
# 14      -1.0   200.0     2024-09-22             True
# 15       2.0   150.0     2024-09-23            False
# 16       1.0     0.0     2024-09-24             True
# 17       1.0   600.0     24-09-2024             True
# 18       2.0  1200.0     2024-09-25             True
# 19       2.0   300.0     09/25/2024             True
# 20       2.0   300.0     09/25/2024             True
# 21       1.0   800.0     2024-09-26            False
# 22       2.0   100.0     2024-09-27             True
# 23       NaN    50.0     2024-09-28             True

# %%
df_withoutnull = dfnew.dropna(inplace=True)

# %%
dfnew.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 14 entries, 0 to 22
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Transaction ID   14 non-null     int64
#  1   Customer Name    14 non-null     object
#  2   Email            14 non-null     object
#  3   Product          14 non-null     object
#  4   Quantity         14 non-null     float64
#  5   Price            14 non-null     float64
#  6   Purchase Date    14 non-null     object
#  7   Delivery Status  14 non-null     bool
# dtypes: bool(1), float64(2), int64(1), object(4)
# memory usage: 910.0+ bytes

# %%
plt.boxplot(df2['Age'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x235c9701160>,
#   <matplotlib.lines.Line2D at 0x235c97012b0>],
#  'caps': [<matplotlib.lines.Line2D at 0x235c9701400>,
#   <matplotlib.lines.Line2D at 0x235c9701550>],
#  'boxes': [<matplotlib.lines.Line2D at 0x235c9701010>],
#  'medians': [<matplotlib.lines.Line2D at 0x235c97016a0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x235c97017f0>],
#  'means': []}

# %%
newdf['Price'].fillna(0, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 newdf['Price'].fillna(0, inplace=True)
#
# NameError: name 'newdf' is not defined

# %%
#column fillna() # mean median mode [0]

#to remove negative value
squared = newdf['Quantity']**2 # squared everything

newQuantity = squared / (squared**0.5) #divide the square with their roots

newQuantity

newdf['Quantity'] = newQuantity
newdf

median_qnty = newdf['Quantity'].median()

# %%
newdf['Price'].quantile(0)

# %%
newdf['Price'].median()

# %%
Q1 = newdf['Price'].quantile(0.25)
Q3 = newdf['Price'].quantile(0.75)

IQR_prices = Q3-Q1
IQR_prices

# %% [markdown]
# outliers in your data, instead of using mean, you can use median, can be better representative of central tendency

# %%
print(newdf['Price'].sort_values())

# %% [markdown]
# df - outliers, missing values, duplication
#
# - dont have outliers
# - missing value
# - duplicates
#
# 1. Check for duplicate
# 2. check for missing values
#     - remove NaN
# 3. Check and remove outliers
# 4. impute them - filling the values

# %%
newdf = df.copy()

mean_price = newdf['Price'].mean().round(2)
print(mean_price)

newdf['Price'].fillna(mean_price, inplace=True)

# %%
mean_quantity = newdf['Quantity'].mean().round(2)
print(mean_quantity)

newdf['Quantity'].fillna(mean_price, inplace=True)

# %%
dfnew.isnull().sum()
# Out:
# Transaction ID     0
# Customer Name      0
# Email              0
# Product            0
# Quantity           0
# Price              0
# Purchase Date      0
# Delivery Status    0
# dtype: int64

# %%
plt.boxplot(df['Quantity'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x235c94b1010>,
#   <matplotlib.lines.Line2D at 0x235c94b1160>],
#  'caps': [<matplotlib.lines.Line2D at 0x235c94b12b0>,
#   <matplotlib.lines.Line2D at 0x235c94b1400>],
#  'boxes': [<matplotlib.lines.Line2D at 0x235c94b0ec0>],
#  'medians': [<matplotlib.lines.Line2D at 0x235c94b1550>],
#  'fliers': [<matplotlib.lines.Line2D at 0x235c94b16a0>],
#  'means': []}

# %%
countnull.index.iloc[2]
