# %% [markdown]
# - Data Storytelling
#
# - Story telling - make a story

# %% [markdown]
# Run any language, we needed an IDE
#
# https://sqliteonline.com/

# %% [markdown]
# In SQL every row is called a record
#
# Create a databse
# Create table
# Query databse and tables
# Create viewa, view a part of the database

# %% [markdown]
# 1. Query a database
#     - can manipulate data within a database
#     - create or retrieve data from a database
#
# 2. CRUS operation on Records
#     - Create
#     - Read
#     - Update
#     - Delete

# %%
SELECT * FROM Departments

# %% [markdown]
# - SELECT - extract data from a databse
# - INSER INTO
# - CREATE DATABSE

# %% [markdown]
# - RUn SQL in a python based version, called SQLite

# %%
CREATE TABLE Department(
	id     INT PRIMARY KEY, #create tbale ->create a new table - specify name
  	name   VARCHAR(50) #created 
)

# %%
pip install sqlite3
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement sqlite3 (from versions: none)
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ERROR: No matching distribution found for sqlite3

# %%
import sqlite3 as sql

# %%
#connet to a databast
#there is no database, when we create a connection, automatically create it

connection = sql.connect('test.db')

# %%
#we need a cursor to point to records in the database - move through the db

cursor = connection.cursor()

# %%
cursor.execute('''
CREATE TABLE students(
    id INT PRIMARY KEY,
    name VARCHAR(10),
    city VARCHAR(10),
    hobby VARCHAR(10)
    )
''')

# %%
#commit the changes and close the connection
connection.commit()

# %%
cursor.execute("INSERT INTO students (id,name,city,hobby) VALUES (1,'Ahirah','Petaling Jaya','Hiking')")
cursor.execute("INSERT INTO students (id,name,city,hobby) VALUES (2,'Ahirah','Petaling Jaya','Hiking')")
cursor.execute("INSERT INTO students (id,name,city,hobby) VALUES (3,'Ahirah','Petaling Jaya','Hiking')")
cursor.execute("INSERT INTO students (id,name,city,hobby) VALUES (4,'Ahirah','Petaling Jaya','Hiking')")

# %%
cursor.execute("SELECT * FROM students")

# %%
#Fetch all result
results = cursor.fetchall()
results
# Out:
# [(1, 'Ahirah', 'Petaling Jaya', 'Hiking'),
#  (2, 'Ahirah', 'Petaling Jaya', 'Hiking'),
#  (3, 'Ahirah', 'Petaling Jaya', 'Hiking'),
#  (4, 'Ahirah', 'Petaling Jaya', 'Hiking')]
