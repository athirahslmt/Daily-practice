# %%
#Let try to bring in the csv file here

import pandas as pd

df = pd.read_csv('CityRating.csv')
df

# %%
df2 = pd.read_csv('CityRating without row number.csv')
df2

# %%
df['citieis'].value_counts() #count unique value
