# %%
import numpy as athirah

# %%
array1 = athirah.array([1,2,3])

# %%
class Std:
    def name(self):
        self.studname=input('Enter your name')

    def display(self):
        print(f'Welcome {self.studname}')

# %%
class Std:
    def __init__(self,name):

    def __str__(self):

# %%
class SelamatDatang:
    name='Athirah'

    def welcome(name):
        return f'Selamat Datang {name}'
