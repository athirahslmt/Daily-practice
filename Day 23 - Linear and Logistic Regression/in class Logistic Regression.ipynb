# %%
#evaluate performance

from sklearn.metrics import accurancy_score, confusion_matrix, classification_report

#confusion matrix

accurancy_test = accurancy_score(y_test, y_pred)
accurancy_test

cm = confusion_matrix(y_test,y_pred)
cm

cr = classification_report(y_test, y_pred)
print(cr)
