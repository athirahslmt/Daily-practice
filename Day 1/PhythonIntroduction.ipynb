# %% [markdown]
# **Phyton Introduction**

# %%
print('Welcome to Phyton')
# Out:
# Welcome to Phyton

# %%
print ('First example in Phyton')
# Out:
# First example in Phyton

# %%
print(10+5)
# Out:
# 15

# %%
#input example
username=input('Enter username : ')
print ('Welcome Mr / Ms  : '+ username)
# Out:
# Enter username :athirah
# Welcome Mr / Ms  :athirah

# %%
num1=12
num2=13
result=num1+num2
print(result)
# Out:
# 25

# %%
# f means for format string literal, if run without f it cannot read the variable
print (f'First Number{num1} and Second Number {num2} Result : {result}')
# Out:
# First Number12 and Second Number 13 Result : 25

# %%
# int for interger to execute whole number
#\t is tab
fnum=int(input('Enter First Number : '))
snum=int(input('Enter Second Number : '))
result = fnum + snum
print (f'Result after adding {fnum} and {snum} is = \t {result}')
# Out:
# Enter First Number : 3
# Enter Second Number : 5
# Result after adding 3 and 5 is = 8

# %%
firstname = 'Sam'
lastname = 'Smith'
fullname = firstname + ' '+ lastname
print(fullname)
# Out:
# Sam Smith

# %%
#type is to know data type
type (firstname)
# Out:
# str

# %%
#{} is for take the value
num=12
type (num)
print(f'Type of fnum {type(fnum)} and snum {type(snum)}')
# Out:
# Type of fnum <class 'int'> and snum <class 'int'>

# %%
#float is for decimal number
fnum=float(input('Enter First Number : '))
snum=float(input('Enter Second Number : '))
result = fnum + snum
print (f'Result after adding {fnum} and {snum} is = \t {result}')
# Out:
# Enter First Number : 9.98
# Enter Second Number : 98.76543
# Result after adding 9.98 and 98.76543 is = 	 108.74543

# %%
#Boolean or bool
is_active=True
type(is_active)
# Out:
# bool

# %%
is_active = False
type (is_active)
# Out:
# bool

# %%
print ('Is active User?',is_active)
# Out:
# Is active User? False

# %%
print(f'Is active User? {is_active}')
# Out:
# Is active User? False

# %%
#Binary Value
byte_ex=b'Hello'
type (byte_ex)

byte_Array=bytearray(b'Hello')
type(byte_Array)

# %%
#complex type
complex_num=2+3j
print(complex_num)
type(complex_num)
# Out:
# (2+3j)
# complex

# %%
#Sequence Type
#list[] - collection of data

list_ex = [10,20,30,40,50]
print(list_ex)
type(list_ex)
# Out:
# [10, 20, 30, 40, 50]
# list

# %%
cars=['Toyota', 'Hyundai','BMW', 'Tesla', 'Audi']
print(cars)
type(cars)
# Out:
# ['Toyota', 'Hyundai', 'BMW', 'Tesla', 'Audi']
# list

# %%
# Tuple - used to store multiple items in a single variable
tuple_ex = (10,20,30,40,50)
print(tuple_ex)
type(tuple_ex)
# Out:
# (10, 20, 30, 40, 50)
# tuple

# %%
#set
set_ex={10,20,30,40,50}
print(set_ex)
type(set_ex)
# Out:
# {50, 20, 40, 10, 30}
# set

# %%
#range
range_ex=range(10)
print(range_ex)
type(range_ex)
# Out:
# range(0, 10)
# range

# %%
range_ex2=range(5)
print(range_ex2)
type(range_ex2)
# Out:
# range(0, 5)
# range

# %%
#Dictionary
emp={
    "id": 1,
    "name":"Sam",
    "salary":20000.76
}
print(emp)
type(emp)
# Out:
# {'id': 1, 'name': 'Sam', 'salary': 20000.76}
# dict
