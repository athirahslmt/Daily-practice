# %% [markdown]
# - Data VIsualization is small part of the overall EDA process
#
# - EDA - Exploratory Data Analysis
#
# - Data Science - Data Analysts ---->
#
# - Data Analysts ---->
#     - tools like Power BI
#     - tableau
#     - Lager volume of data - large quantity
#         - 300 rows is not large
#         - 10k around data fair amount of data
#         - 400k rows of data
#
# - To be able to find data - data sources
#
# - Import that data into your python  files (1)
#
# - should be able to analyse it (2)
#     - by using visualization tools we learnt
#     - matplolib and seaborn

# %% [markdown]
# 1. Find data related to the titanic ship
#     - download it
#     - import to nbs
#     - make some visualization
#     - and finally, write 4 lines about the data (give some data that is not easily observable - make some judgements/inference)

# %%
import pandas

# %%
pip install matplotlib
# Out:
# ...
#    ---------------------------------------- 0.0/8.3 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.3 MB ? eta -:--:--
#    --- ------------------------------------ 0.8/8.3 MB 1.6 MB/s eta 0:00:05
#    ----- ---------------------------------- 1.0/8.3 MB 1.6 MB/s eta 0:00:05
#    ------- -------------------------------- 1.6/8.3 MB 1.7 MB/s eta 0:00:04
#    ---------- ----------------------------- 2.1/8.3 MB 1.7 MB/s eta 0:00:04
#    ----------- ---------------------------- 2.4/8.3 MB 1.8 MB/s eta 0:00:04
#    ------------- -------------------------- 2.9/8.3 MB 1.8 MB/s eta 0:00:04
#    ---------------- ----------------------- 3.4/8.3 MB 1.9 MB/s eta 0:00:03
#    -------------------- ------------------- 4.2/8.3 MB 1.9 MB/s eta 0:00:03
#    --------------------- ------------------ 4.5/8.3 MB 1.9 MB/s eta 0:00:03
#    ------------------------- -------------- 5.2/8.3 MB 2.0 MB/s eta 0:00:02
#    -------------------------- ------------- 5.5/8.3 MB 1.9 MB/s eta 0:00:02
# ...

# %%
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
import pandas as pd

# %%
df = pd.read_csv("Titanic-Dataset.csv")
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import seaborn as sns

# %%
sns.scatterplot(data = df, x='Pclass' , y='Survived')
# Out:
# <Axes: xlabel='Pclass', ylabel='Survived'>

# %%
sns.pairplot(health,hue='Country')

# %%
# load data
df = sns.load_dataset(ship)
ship.head()

# %%
df2 = pd.read_csv("crime_district.csv")
df2.head()
df2.tail()
# Out:
#                    state     district  category                      type  \
# 19147  W.P. Kuala Lumpur  Wangsa Maju  property  theft_vehicle_motorcycle
# 19148  W.P. Kuala Lumpur  Wangsa Maju  property  theft_vehicle_motorcycle
# 19149  W.P. Kuala Lumpur  Wangsa Maju  property  theft_vehicle_motorcycle
# 19150  W.P. Kuala Lumpur  Wangsa Maju  property  theft_vehicle_motorcycle
# 19151  W.P. Kuala Lumpur  Wangsa Maju  property  theft_vehicle_motorcycle
#
#              date  crimes
# 19147  2019-01-01     755
# 19148  2020-01-01     646
# 19149  2021-01-01     403
# 19150  2022-01-01     369
# 19151  2023-01-01     358

# %%
df2.shape
# Out:
# (19152, 6)

# %%
plt.bar(df2['state'], df2['crimes'])

plt.xlabel("state")
plt.ylabel("crimes")
plt.title("Crime Rate in Malaysia")

plt.xticks(rotation=45, ha='right') # Rotate x-axis labels if they overlap
plt.tight_layout()

plt.show()

# %%
plt.bar(df2['category'], df2['crimes'])

plt.xlabel("category")
plt.ylabel("crimes")
plt.title("Crime Rate in Malaysia")

plt.xticks(rotation=45, ha='right') # Rotate x-axis labels if they overlap
plt.tight_layout()

plt.show()

# %%
plt.bar(df2['type'], df2['crimes'])

plt.xlabel("type" \
"")
plt.ylabel("crimes")
plt.title("Crime Rate in Malaysia")

plt.xticks(rotation=45, ha='right') # Rotate x-axis labels if they overlap
plt.tight_layout()

plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
print(df_2020.head())
print("Jumlah rekod 2020:", len(df_2020))
print(df_2020['state'].unique())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 print(df_2020.head())
#       2 print("Jumlah rekod 2020:", len(df_2020))
#       3 print(df_2020['state'].unique())
#
# NameError: name 'df_2020' is not defined

# %%
df['date'] = pd.to_datetime(df['date'])
df_2020 = df[df['date'].dt.year == 2020]

state_2020 = df_2020.groupby('state')['crimes'].sum().sort_values(ascending=False)

plt.figure(figsize=(12,6))
state_2020.plot(kind='bar')
plt.title("Jenayah Mengikut Negeri (2020)")
plt.xlabel("state")
plt.ylabel("crimes")
plt.tight_layout()
plt.show()

# %%
import pandas as pd

df = pd.read_csv('iris.csv')
df.shape
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 3
#       1 import pandas as pd
# ----> 3 df = pd.read_csv('iris.csv')
#       4 df.shape
#
# ...
