# %% [markdown]
# - finding the data
#
# # Data Source
# - Primary source
#     - data that we collect ourselves
#     - problem - people you meet?
#     - sensor data
#         - sensors sensr environment data
#             - proximity sensors - if you are close to the door
#             - temperature sensor
#     -you have to invest time, effort inti this
#     - need infrastructure
#     - even money
#     - researchers, people who have incentive like
# - Secondary - Rely on this a lot
#     - data that you get from someone else
#     - computer, looking for data and you download it
#
#     -kaggle

# %%
import seaborn as sb

# %%
titanic = titanic.dropna()

# %%
titanic['age']=titanic['age'].astype('int64')

# %%
titanic['fare']=titanic['age'].astype('int64')

# %% [markdown]
# 1. What the problem is :
#     Increasing crime rate in Malaysia
#
# 2. Who the solution is for :
#     Malaysian
#
# 3. Where is the problem occuring :
#     All district in Malaysia
#
# 4. Why is worth solving :
#     Reduce crime rate
